# %%
# this is the task of day1 
# We learn the commands of git and github 
# Create a branched repository and push the code to the repository

# %%
a  = int(input("Enter Value"))
b =  int(input("Enter 2 Value"))
print(a  + b)

# %%
# here the evening task:
#Theory part of day1 is to learn about the data types and how to use them in python.


# vedio lecture 1 includes the following topics:
# 1: Modularization
# 2: Python Blocks
# 3: Python Functions

# vedio lecture 2 includes the following topics:
# 1: Python Function Comments
# 2: Python Function Parameters and set type to function parameters
# 3: Python Data Types and using Python Built-In type() function
# 4: Operator Loading
# 5: New Line String

# vedio lecture 3 includes the following topics:
# 1: Proper usage of Hard Coding
# 2: Python Built-In Input() Function
# 3: Standard Inputs
# 4: Type Casting or Type Conversion

# vedio lecture 4 includes the following topics:
# 1: Python Error Handling
# 2: Python Runtime Errors 
# 3: Python try: and except: Block
# 4: Python Built-In Errors
# 5: Python Best Programming Practices

# %%
# this is the task of day1 
# We learn the commands of git and github 
# Create a branched repository and push the code to the repository

# %%
a  = int(input("Enter Value"))
b =  int(input("Enter 2 Value"))
print(a  + b)
# Out:
# 3

# %%
# here the evening task:
#Theory part of day1 is to learn about the data types and how to use them in python.


# vedio lecture 1 includes the following topics:
# 1: Modularization
# 2: Python Blocks
# 3: Python Functions

# vedio lecture 2 includes the following topics:
# 1: Python Function Comments
# 2: Python Function Parameters and set type to function parameters
# 3: Python Data Types and using Python Built-In type() function
# 4: Operator Loading
# 5: New Line String

# vedio lecture 3 includes the following topics:
# 1: Proper usage of Hard Coding
# 2: Python Built-In Input() Function
# 3: Standard Inputs
# 4: Type Casting or Type Conversion

# vedio lecture 4 includes the following topics:
# 1: Python Error Handling
# 2: Python Runtime Errors 
# 3: Python try: and except: Block
# 4: Python Built-In Errors
# 5: Python Best Programming Practices
